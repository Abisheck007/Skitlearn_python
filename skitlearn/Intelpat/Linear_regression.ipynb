# %%
from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
x,y = datasets.load_iris(return_X_y=True)
plt.scatter(x[:,0],y)

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2)

# %%
model = LinearRegression()
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
prediction = model.predict(xtest)
prediction
# Out:
# array([-2.27390187e-02,  1.36342932e-02,  1.92732561e+00,  1.15923595e+00,
#         2.10675866e+00,  2.01057976e+00,  2.25383513e+00,  1.85519466e+00,
#         1.67802941e+00,  1.28392566e+00,  1.60234969e+00,  1.73439509e+00,
#         1.24757801e+00,  1.40446722e+00,  2.18359290e+00,  1.71662331e+00,
#         1.47345952e+00,  1.10555442e+00,  1.19011124e+00,  1.31497575e+00,
#         1.89872322e+00,  1.37998633e+00,  1.05174133e+00, -8.18909971e-03,
#         1.92199302e+00,  4.60898591e-04,  1.73740218e+00, -2.18327737e-03,
#         1.02789505e-01,  9.21540275e-01])

# %%
plt.scatter(prediction,ytest)

# %%
#to find the accuracy
print(model.score(x,y))
print(model.coef_)
print(model.intercept_)
# Out:
# 0.9299070517702737
# [-0.09401487 -0.0562958   0.17933254  0.69713875]
# 0.21306282818942945
